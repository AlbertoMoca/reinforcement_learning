# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
mu, sigma = 0, 1 
samples_per_action = 200
centers = np.random.normal(mu, sigma, 20)

# %%
all_data = [np.random.normal(c, 1, samples_per_action) for c in centers]

# %%
plt.violinplot(all_data,showmeans=True)
plt.show()

# %%
Q
# Out:
# array([-1.57117721,  1.09710666,  2.27659273, -1.00670712,  1.24246341,
#        -1.92857948,  0.47872599,  0.35942197, -0.91933985,  0.83374762])

# %%
np.argmax(Q)
# Out:
# 2

# %%
Q = np.random.normal(0, 1, 10)

# %%
q = centers.copy()

# %%
def updateQ(samples,Q,epsilon,iterations,parallel_tries):
    Q = Q.copy()
    Qs = np.reshape(np.repeat(Q, parallel_tries),(len(Q),parallel_tries)).T
    
    mean_trace = []
    
    for i in range(iterations):
        iteration_reward = 0
        for try_id in range(len(Qs)):
            if np.random.rand() < epsilon:
                a = np.random.randint(len(Q))
                
            else:
                a = np.argmax(Qs[try_id])
            
            reward = np.random.choice(all_data[a])
            iteration_reward += reward
            Qs[try_id][a] += .3*(reward - Qs[try_id][a])
        mean_trace.append(iteration_reward/parallel_tries)
    return mean_trace

# %%
plt.plot(updateQ(all_data,Q.copy(),0,300,1000),c="y")
plt.plot(updateQ(all_data,Q.copy(),.01,300,1000),c="c")
plt.plot(updateQ(all_data,Q.copy(),.1,300,1000),c="m")
plt.plot(updateQ(all_data,Q.copy(),.9,300,1000),c="b")
